# %% [markdown]
# <a href="https://colab.research.google.com/github/Sunhokim2/first-test-project/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1+1

# %%
2+3
# Out:
# 5

# %%
f=open("test.txt","w")

# %%
f.write("what\n are you \n doing? ")
f.close()

# %%
f= open("programming.csv","w")

# %% [markdown]
# ddddd

# %%
name = ['name','python','java','R','C']
rate = ['rate','상','중','하','중']

# %%
len(name)
# Out:
# 5

# %%
for i in range(len(name)):
    f.write(name[i]+","+rate[i]+"\n")

# %%
f.close()

# %%
import pandas as pd

# %%
data = [
    [1,2,3,4,5],
    ['a','b','c','d','e']
]

# %%
df = pd.DataFrame(data, columns=['col1','col2','col3','col4','col5'])

# %%
df['col1_test'] = 1

# %%
df
# Out:
#   col1 col2 col3 col4 col5  col1_test
# 0    1    2    3    4    5          1
# 1    a    b    c    d    e          1

# %%
df.to_csv("test02.csv",index=False)

# %%
import openpyxl #pip install openpyxl

# %%
wb = openpyxl.Workbook()

sheet = wb.active
sheet['A1'] = 'Test openpyxl'
sheet.cell(row= 3, column = 1).value = 'TEST'

name = ['PYTHON','JAVA','R','C']
sheet.append(name)

wb.save('test03.xlsx')

# %%
df.to_excel('text03.xlsx',sheet_name='pandas_excel')

# %% [markdown]
# # **판다스 본격활용**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 데이터 오브젝트 생성

# %%
s = pd.Series([1,3,5,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
dates = pd.date_range('20130101',periods=6)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.092279 -0.134317 -0.443088 -0.981112
# 2013-01-02 -0.285911  0.183026  2.277574 -0.016052
# 2013-01-03 -0.045670 -1.342986 -0.839011 -0.027718
# 2013-01-04  2.114315  0.129275  2.034738  0.328837
# 2013-01-05  1.001433 -0.258384 -0.596760 -1.402910
# 2013-01-06  1.431644  0.517141  1.156701 -0.598145

# %%
dates = pd.date_range('20130101',periods=6)
a = pd.DataFrame(np.random.randn(6,4),index=dates,columns=list('ABCD'))

dates_str = ['2013-01-01','2013-01-02','2013-01-03','2013-01-04','2013-01-05','2013-01-06']
b=pd.DataFrame(np.random.randn(6,4), index =dates_str, columns = list('ABCD'))

# %%
a.head(3)
# Out:
#                    A         B         C         D
# 2013-01-01 -0.100549  1.616181 -1.961383 -1.499119
# 2013-01-02 -0.485122 -0.688011  0.233611 -0.654811
# 2013-01-03  0.546344 -0.888921  0.353126 -0.806388

# %%
b
# Out:
#                    A         B         C         D
# 2013-01-01 -0.662960 -0.189548 -1.718325 -1.737701
# 2013-01-02 -0.512896 -0.313674 -0.044427 -0.447550
# 2013-01-03  0.816398 -3.376445 -1.393292  1.947716
# 2013-01-04 -1.414367  2.144457  0.319725  0.211176
# 2013-01-05 -0.327884 -0.288223  0.447703 -1.435152
# 2013-01-06  0.516010 -0.369441 -1.082295 -1.102837

# %%
b['B'] = [str(i) for i in b['B'].tolist()]
b['C'] = [round(i,2) for i in b['C'].tolist()]

# %%
b
# Out:
#                    A                     B     C         D
# 2013-01-01 -0.662960  -0.18954819422424227 -1.72 -1.737701
# 2013-01-02 -0.512896   -0.3136741021492034 -0.04 -0.447550
# 2013-01-03  0.816398    -3.376444687839336 -1.39  1.947716
# 2013-01-04 -1.414367     2.144457101602453  0.32  0.211176
# 2013-01-05 -0.327884  -0.28822291691305346  0.45 -1.435152
# 2013-01-06  0.516010  -0.36944056379744433 -1.08 -1.102837

# %%
type(b.iloc[0,1]), b.iloc[0,1] #수가 아닌 문자로 변경되어있는상태다
# Out:
# (str, '-0.18954819422424227')

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -1.092279 -0.134317 -0.443088 -0.981112
# 2013-01-02 -0.285911  0.183026  2.277574 -0.016052
# 2013-01-03 -0.045670 -1.342986 -0.839011 -0.027718
# 2013-01-04  2.114315  0.129275  2.034738  0.328837
# 2013-01-05  1.001433 -0.258384 -0.596760 -1.402910

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.520589 -0.151041  0.598359 -0.449517
# std    1.197801  0.643301  1.398116  0.661103
# min   -1.092279 -1.342986 -0.839011 -1.402910
# 25%   -0.225851 -0.227368 -0.558342 -0.885370
# 50%    0.477882 -0.002521  0.356806 -0.312931
# 75%    1.324091  0.169589  1.815228 -0.018969
# max    2.114315  0.517141  2.277574  0.328837

# %%
df.transpose()
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -1.092279   -0.285911   -0.045670    2.114315    1.001433    1.431644
# B   -0.134317    0.183026   -1.342986    0.129275   -0.258384    0.517141
# C   -0.443088    2.277574   -0.839011    2.034738   -0.596760    1.156701
# D   -0.981112   -0.016052   -0.027718    0.328837   -1.402910   -0.598145

# %%
df.sort_index(axis=0,ascending=False)
# Out:
#                    A         B         C         D
# 2013-01-06  1.431644  0.517141  1.156701 -0.598145
# 2013-01-05  1.001433 -0.258384 -0.596760 -1.402910
# 2013-01-04  2.114315  0.129275  2.034738  0.328837
# 2013-01-03 -0.045670 -1.342986 -0.839011 -0.027718
# 2013-01-02 -0.285911  0.183026  2.277574 -0.016052
# 2013-01-01 -1.092279 -0.134317 -0.443088 -0.981112

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2013-01-03 -0.045670 -1.342986 -0.839011 -0.027718
# 2013-01-05  1.001433 -0.258384 -0.596760 -1.402910
# 2013-01-01 -1.092279 -0.134317 -0.443088 -0.981112
# 2013-01-04  2.114315  0.129275  2.034738  0.328837
# 2013-01-02 -0.285911  0.183026  2.277574 -0.016052
# 2013-01-06  1.431644  0.517141  1.156701 -0.598145

# %%
df.loc['2013-01-01':'2013-01-03','A':'C']
# Out:
#                    A         B         C
# 2013-01-01 -1.092279 -0.134317 -0.443088
# 2013-01-02 -0.285911  0.183026  2.277574
# 2013-01-03 -0.045670 -1.342986 -0.839011

# %%
s1 = pd.Series([1,2,3,4,5,6],index=pd.date_range('20130102',periods=6))

# %%
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df.mean()
# Out:
# A    0.520589
# B   -0.151041
# C    0.598359
# D   -0.449517
# dtype: float64

# %%
df.mean(1)
# Out:
# 2013-01-01   -0.662699
# 2013-01-02    0.539659
# 2013-01-03   -0.563846
# 2013-01-04    1.151791
# 2013-01-05   -0.314155
# 2013-01-06    0.626835
# Freq: D, dtype: float64

# %%
s=pd.Series([1,3,5,np.nan,np.nan,8], index = dates).shift(2)
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s,axis='index')
# Out:
#                    A         B         C         D
# 2013-01-01       NaN       NaN       NaN       NaN
# 2013-01-02       NaN       NaN       NaN       NaN
# 2013-01-03 -1.045670 -2.342986 -1.839011 -1.027718
# 2013-01-04 -0.885685 -2.870725 -0.965262 -2.671163
# 2013-01-05 -3.998567 -5.258384 -5.596760 -6.402910
# 2013-01-06       NaN       NaN       NaN       NaN

# %%
df.sub(s)
# Out:
#             2013-01-01 00:00:00  2013-01-02 00:00:00  2013-01-03 00:00:00  \
# 2013-01-01                  NaN                  NaN                  NaN
# 2013-01-02                  NaN                  NaN                  NaN
# 2013-01-03                  NaN                  NaN                  NaN
# 2013-01-04                  NaN                  NaN                  NaN
# 2013-01-05                  NaN                  NaN                  NaN
# 2013-01-06                  NaN                  NaN                  NaN
#
#             2013-01-04 00:00:00  2013-01-05 00:00:00  2013-01-06 00:00:00   A  \
# 2013-01-01                  NaN                  NaN                  NaN NaN
# 2013-01-02                  NaN                  NaN                  NaN NaN
# 2013-01-03                  NaN                  NaN                  NaN NaN
# 2013-01-04                  NaN                  NaN                  NaN NaN
# ...
